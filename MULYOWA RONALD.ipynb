# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
# Reading the dataset
map_data = pd.read_excel('Interview Challenge.xlsx')

# %%
# Displaying the data
map_data.head()
# Out:
#                                  id  latitudes/0  latitudes/1  latitudes/2  \
# 0  7590cf21d1a446e3b07c92912a4a3c44     2.980511     2.980595     2.980763
# 1  c7b3fde63650440abbaaecec33e30bfa     2.965254     2.965177     2.965122
# 2  ef2b90b7ff804894a8413477cdfa0e86     2.961134     2.961096     2.961096
# 3  604a8069c5bb4620b7394a7ec5603c18     2.961075     2.961193     2.960932
# 4  9848201f11824ca5a7639aee61152122     2.960971     2.961101     2.961128
#
#    latitudes/3  longitudes/0  longitudes/1  longitudes/2  longitudes/3  \
# 0     2.980530     32.531686     32.531705     32.531327     32.531240
# 1     2.966003     32.249756     32.250017     32.250278     32.250418
# 2     2.961162     32.240426     32.240401     32.240401     32.240312
# 3     2.960932     32.240455     32.240537     32.240490     32.240490
# 4     2.961035     32.240536     32.240386     32.240551     32.240573
#
#    latitudes/4  longitudes/4  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0     2.980515     32.531657          NaN          NaN          NaN
# 1     2.965983     32.249870          NaN          NaN          NaN
# 2     2.960957     32.240535          NaN          NaN          NaN
# 3     2.961053     32.240440          NaN          NaN          NaN
# 4     2.960998     32.240462          NaN          NaN          NaN
#
#    Unnamed: 14 Unnamed: 15
# 0          NaN         NaN
# 1          NaN           s
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN

# %%
# Understanding the data types for the various columns
map_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            5 non-null      object
#  1   latitudes/0   5 non-null      float64
#  2   latitudes/1   5 non-null      float64
#  3   latitudes/2   5 non-null      float64
#  4   latitudes/3   5 non-null      float64
#  5   longitudes/0  5 non-null      float64
#  6   longitudes/1  5 non-null      float64
#  7   longitudes/2  5 non-null      float64
#  8   longitudes/3  5 non-null      float64
#  9   latitudes/4   5 non-null      float64
#  10  longitudes/4  5 non-null      float64
#  11  Unnamed: 11   0 non-null      float64
#  12  Unnamed: 12   0 non-null      float64
#  13  Unnamed: 13   0 non-null      float64
#  14  Unnamed: 14   0 non-null      float64
#  15  Unnamed: 15   1 non-null      object
# dtypes: float64(14), object(2)
# memory usage: 768.0+ bytes

# %% [markdown]
#  ### Issues that need to be cleaned
#  ###### It can be seen that the number of longitudes exceeds the number of latitudes
#  ###### There are multiple unnamed columns which need to be excluded from the data set

# %%
### Removing the unnamed Columns, and excess longitudes

# %%
new_map_data = map_data[['id', 'latitudes/0', 'latitudes/1','latitudes/2', 'latitudes/3', 'longitudes/0', 'longitudes/1', 'longitudes/2', 'longitudes/3']]
new_map_data.head()
# Out:
#                                  id  latitudes/0  latitudes/1  latitudes/2  \
# 0  7590cf21d1a446e3b07c92912a4a3c44     2.980511     2.980595     2.980763
# 1  c7b3fde63650440abbaaecec33e30bfa     2.965254     2.965177     2.965122
# 2  ef2b90b7ff804894a8413477cdfa0e86     2.961134     2.961096     2.961096
# 3  604a8069c5bb4620b7394a7ec5603c18     2.961075     2.961193     2.960932
# 4  9848201f11824ca5a7639aee61152122     2.960971     2.961101     2.961128
#
#    latitudes/3  longitudes/0  longitudes/1  longitudes/2  longitudes/3
# 0     2.980530     32.531686     32.531705     32.531327     32.531240
# 1     2.966003     32.249756     32.250017     32.250278     32.250418
# 2     2.961162     32.240426     32.240401     32.240401     32.240312
# 3     2.960932     32.240455     32.240537     32.240490     32.240490
# 4     2.961035     32.240536     32.240386     32.240551     32.240573

# %%
# Renaming the Columns
new_map_data = new_map_data.rename(columns={'latitudes/0':'latitude_zero', 'latitudes/1':'latitude_one','latitudes/2':'latitude_two', 'latitudes/3':'latitude_three', 'longitudes/0':'longitude_zero', 'longitudes/1':'longitude_one', 'longitudes/2':'longitude_two', 'longitudes/3':'longitude_3'})

# %%
new_map_data.head(20)
# Out:
#                                  id  latitude_zero  latitude_one  \
# 0  7590cf21d1a446e3b07c92912a4a3c44       2.980511      2.980595
# 1  c7b3fde63650440abbaaecec33e30bfa       2.965254      2.965177
# 2  ef2b90b7ff804894a8413477cdfa0e86       2.961134      2.961096
# 3  604a8069c5bb4620b7394a7ec5603c18       2.961075      2.961193
# 4  9848201f11824ca5a7639aee61152122       2.960971      2.961101
#
#    latitude_two  latitude_three  longitude_zero  longitude_one  longitude_two  \
# 0      2.980763        2.980530       32.531686      32.531705      32.531327
# 1      2.965122        2.966003       32.249756      32.250017      32.250278
# 2      2.961096        2.961162       32.240426      32.240401      32.240401
# 3      2.960932        2.960932       32.240455      32.240537      32.240490
# 4      2.961128        2.961035       32.240536      32.240386      32.240551
#
#    longitude_3
# 0    32.531240
# 1    32.250418
# 2    32.240312
# 3    32.240490
# 4    32.240573

# %%
new_map_data.describe()
# Out:
#        latitude_zero  latitude_one  latitude_two  latitude_three  \
# count       5.000000      5.000000      5.000000        5.000000
# mean        2.965789      2.965833      2.965808        2.965932
# std         0.008428      0.008437      0.008544        0.008439
# min         2.960971      2.961096      2.960932        2.960932
# 25%         2.961075      2.961101      2.961096        2.961035
# 50%         2.961134      2.961193      2.961128        2.961162
# 75%         2.965254      2.965177      2.965122        2.966003
# max         2.980511      2.980595      2.980763        2.980530
#
#        longitude_zero  longitude_one  longitude_two  longitude_3
# count        5.000000       5.000000       5.000000     5.000000
# mean        32.300572      32.300609      32.300609    32.300607
# std          0.129259       0.129253       0.129045     0.129000
# min         32.240426      32.240386      32.240401    32.240312
# 25%         32.240455      32.240401      32.240490    32.240490
# 50%         32.240536      32.240537      32.240551    32.240573
# 75%         32.249756      32.250017      32.250278    32.250418
# max         32.531686      32.531705      32.531327    32.531240

# %%
lats0 = new_map_data['latitude_zero'].values
lons1 = new_map_data['longitude_zero'].values

# %%
# creating a base to map latitudes and longitudes

#map = Basemap(projection='aeqd', llcrnrlat=2.960971, urcrnrlat= 2.980511, llcrnrlon=32.240426, urcrnrlon=32.531686, lon_0=32.240536, lat_0=2.961134)
#print(map(2.961134,32.240536))

# %%
## Map background
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc',  
            lat_0=2.961134 , lon_0=32.240536,)
m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='gray')
m.drawstates(color='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-fc3512291176> in <module>
#       2 fig = plt.figure(figsize=(8, 8))
#       3 m = Basemap(projection='lcc',
# ----> 4             lat_0=2.961134 , lon_0=32.240536,
#       5             )
#       6 m.shadedrelief()
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in __init__(self, llcrnrlon, llcrnrlat, urcrnrlon, urcrnrlat, llcrnrx, llcrnry, urcrnrx, urcrnry, width, height, projection, resolution, area_thresh, rsphere, ellps, lat_ts, lat_1, lat_2, lat_0, lon_0, lon_1, lon_2, o_lon_p, o_lat_p, k_0, no_rot, suppress_ticks, satellite_height, boundinglat, fix_aspect, anchor, celestial, round, epsg, ax)
#     748                 else:
#     749                     if width is None or height is None:
# --> 750                         raise ValueError('must either specify lat/lon values of corners (llcrnrlon,llcrnrlat,urcrnrlon,urcrnrlat) in degrees or width and height in meters')
#     751                     if lon_0 is None or lat_0 is None:
#     752                         raise ValueError('must specify lon_0 and lat_0 when using width, height to specify projection region')
#
# ValueError: must either specify lat/lon values of corners (llcrnrlon,llcrnrlat,urcrnrlon,urcrnrlat) in degrees or width and height in meters

# %%
cmap = Basemap(projection='tmerc', 
              lat_0=2.961134 , lon_0=32.240536,
              llcrnrlon=32.240426, 
              llcrnrlat=2.960971 
              urcrnrlon=32.531686, 
              urcrnrlat=2.980511)



x = linspace(0, cmap.urcrnrx, new_map_data['latitude_zero'])
y = linspace(0, cmap.urcrnry, new_map_data['longitude_zero'])

xx, yy = meshgrid(x, y)

cmap.contour(xx, yy, data)

plt.show()
